# %%
import numpy as np
import pandas as pd
import pymorphy2
from tqdm.notebook import tqdm as tn
import nltk
import regex as re

# %%
data_spbu = pd.read_csv(r"C:\Users\User\Downloads\spbu_content.csv", header = None)
data_spbu.head(5)
# Out:
#                                            0                             1  \
# 0                           https://spbu.ru/  2023-04-14T00:56:50.6368499Z
# 1     https://cabinet.spbu.ru/Account/LogOn/  2023-04-14T00:57:02.6226399Z
# 2                         http://bb.spbu.ru/  2023-04-14T00:57:02.6225294Z
# 3                    https://events.spbu.ru/  2023-04-14T00:57:03.8827793Z
# 4  https://cabinet.spbu.ru/Account/Register/  2023-04-14T00:57:06.6414451Z
#
#                                                    2
# 0      Главная | Санкт-Петербургский государствен...
# 1                                      Вход      ...
# 2    Blackboard Learn                            ...
# 3                                                ...
# 4                                      Регистраци...

# %%
data_spbu.iloc[0, 2]
# Out:
# '    Главная | Санкт-Петербургский государственный университет                                                                                                                                                                                       299 дней осталось до 300-летия СПбГУ                                                                    \t  \t    \t        Открытый университет\t    \t    \t    \t      \t         \t           \t              Политика открытости\t           \t          \t           \t              Документы\t           \t          \t           \t              Противодействие коррупции\t           \t          \t           \t              Виртуальная приемная\t           \t          \t           \t              Ректорские совещания\t           \t          \t           \t              Ученый совет\t           \t          \t           \t              Перезагрузка\t           \t          \t           \t              Сведения об образовательной организации\t           \t          \t           \t              Материалы приема граждан\t           \t          \t           \t              Общественное обсуждение\t           \t          \t           \t              Общественные организации\t           \t          \t           \t              СПбГУ и Цели устойчивого развития\t           \t          \t      \t      \t         \t           \t               Абитуриентам\t           \t         \t           \t               Студентам\t           \t         \t           \t               Сотрудникам\t           \t         \t           \t               Выпускникам\t           \t         \t           \t               Работодателям\t           \t         \t           \t               Работа в СПбГУ\t           \t         \t      \t    \t    \t    \t  \t    \t        Экспертный университет\t    \t    \t    \t  \t    \t        Работа в СПбГУ\t    \t    \t    \t  \t    \t        Контакты\t    \t    \t          EN        中文                                          Университет                                                                  История университета                                                  Ректор СПбГУ                                                  Подразделения и руководство                                                  Учебно-научные подразделения                                                  Попечительский совет                                                  Университет в лицах                                                  Музеи и коллекции СПбГУ                                                  Партнеры                                                  Онлайн-курсы СПбГУ                                                  Клиника СПбГУ                                                  Международная деятельность                                                  Эндаумент-фонд СПбГУ                                                  Интернет-магазин СПбГУ                                                                                             Наш университет                                                                                  Поступающим                                                                  Приемная комиссия                                                  Образовательные программы                                                  Дополнительное образование                                                  Календарь приема                                                  Правовая помощь                                                  Подготовка к ЕГЭ                                                  Онлайн-курсы СПбГУ                                                                                             Поступайте с умом                                                                                  Студентам                                                                  Студенческий совет                                                  Студенческий кампус               ...

# %%
data_msu = pd.read_csv(r"C:\Users\User\Downloads\msu_content.csv", header = None)
data_msu.head(5)
# Out:
#                                      0                             1  \
# 0                      https://msu.ru/  2023-04-15T16:29:55.1662631Z
# 1             https://msu.ru/news/rss/  2023-04-15T16:30:13.1464229Z
# 2                   http://270.msu.ru/  2023-04-15T16:30:09.1446391Z
# 3  https://conf.msu.ru/rus/event/8147/  2023-04-15T16:30:09.1695835Z
# 4                  http://nosh.msu.ru/  2023-04-15T16:30:11.2455821Z
#
#                                                    2
# 0  \t\tМосковский государственный университет име...
# 1  \tНовости МГУhttp://www.msu.ruSat, 15 Apr 2023...
# 2   270 лет Московскому университету     Указ Пре...
# 3                                                ...
# 4   Научно-образовательные школы Московского унив...

# %%
nltk.download('stopwords')
russian_stopwords = nltk.corpus.stopwords.words('russian')
english_stopwords = nltk.corpus.stopwords.words('english')

word_tokenizer = nltk.WordPunctTokenizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('wordnet')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()
word_list = nltk.word_tokenize(data_spbu.iloc[205, 2].lower()) # токенизированная строка
print(word_list)
# Out:
# ['%', 'pdf-1.7', '%', '����8', '0', 'obj', '<', '>', 'endobj', 'xref8', '3610000000016', '00000', 'n0000008222', '00000', 'n0000008342', '00000', 'n0000009654', '00000', 'n0000009784', '00000', 'n0000009920', '00000', 'n0000010056', '00000', 'n0000010191', '00000', 'n0000010326', '00000', 'n0000010464', '00000', 'n0000010602', '00000', 'n0000010740', '00000', 'n0000010876', '00000', 'n0000011012', '00000', 'n0000011148', '00000', 'n0000011284', '00000', 'n0000011420', '00000', 'n0000011555', '00000', 'n0000011690', '00000', 'n0000011826', '00000', 'n0000011963', '00000', 'n0000012393', '00000', 'n0000012916', '00000', 'n0000013418', '00000', 'n0000013838', '00000', 'n0000014297', '00000', 'n0000014332', '00000', 'n0000014359', '00000', 'n0000019445', '00000', 'n0000028721', '00000', 'n0000037851', '00000', 'n0000047477', '00000', 'n0000057225', '00000', 'n0000067200', '00000', 'n0000079207', '00000', 'n0000090503', '00000', 'n0000093152', '00000', 'n0000093265', '00000', 'n0000093377', '00000', 'n0000093488', '00000', 'n0000093613', '00000', 'n0000093728', '00000', 'n0000102550', '00000', 'n0000102808', '00000', 'n0000103277', '00000', 'n0000113714', '00000', 'n0000113972', '00000', 'n0000114523', '00000', 'n0000123490', '00000', 'n0000123769', '00000', 'n0000124257', '00000', 'n0000132076', '00000', 'n0000132337', '00000', 'n0000132776', '00000', 'n0000139646', '00000', 'n0000139910', '00000', 'n0000140309', '00000', 'n0000140696', '00000', 'n0000140791', '00000', 'n0000140934', '00000', 'n0000141045', '00000', 'n0000141275', '00000', 'n0000141662', '00000', 'n0000141780', '00000', 'n0000141923', '00000', 'n0000141995', '00000', 'n0000142118', '00000', 'n0000142231', '00000', 'n0000142344', '00000', 'n0000142413', '00000', 'n0000142509', '00000', 'n0000151195', '00000', 'n0000151487', '00000', 'n0000151896', '00000', 'n0000151921', '00000', 'n0000152418', '00000', 'n0000152558', '00000', 'n0000152627', '00000', 'n0000152723', '00000', 'n0000162692', '00000', 'n0000162963', '00000', 'n0000163388', '00000', 'n0000163413', '00000', 'n0000163956', '00000', 'n0000164086', '00000', 'n0000164155', '00000', 'n0000164243', '00000', 'n0000169994', '00000', 'n0000170277', '00000', 'n0000170520', '00000', 'n0000170545', '00000', 'n0000170889', '00000', 'n0000171025', '00000', 'n0000171095', '00000', 'n0000171186', '00000', 'n0000176772', '00000', 'n0000177057', '00000', 'n0000177297', '00000', 'n0000177324', '00000', 'n0000177685', '00000', 'n0000177823', '00000', 'n0000177893', '00000', 'n0000177986', '00000', 'n0000184757', '00000', 'n0000185065', '00000', 'n0000185372', '00000', 'n0000185399', '00000', 'n0000185806', '00000', 'n0000185954', '00000', 'n0000186024', '00000', 'n0000186118', '00000', 'n0000192889', '00000', 'n0000193180', '00000', 'n0000193491', '00000', 'n0000193518', '00000', 'n0000193924', '00000', 'n0000194064', '00000', 'n0000194246', '00000', 'n0000194414', '00000', 'n0000252562', '00000', 'n0000252601', '00000', 'n0000252989', '00000', 'n0000253086', '00000', 'n0000253231', '00000', 'n0000253304', '00000', 'n0000253378', '00000', 'n0000253752', '00000', 'n0000253826', '00000', 'n0000254201', '00000', 'n0000254275', '00000', 'n0000254651', '00000', 'n0000254725', '00000', 'n0000255101', '00000', 'n0000255175', '00000', 'n0000255551', '00000', 'n0000255625', '00000', 'n0000256001', '00000', 'n0000256075', '00000', 'n0000256451', '00000', 'n0000256525', '00000', 'n0000256902', '00000', 'n0000256976', '00000', 'n0000257352', '00000', 'n0000257426', '00000', 'n0000257802', '00000', 'n0000257876', '00000', 'n0000258249', '00000', 'n0000258323', '00000', 'n0000258699', '00000', 'n0000258773', '00000', 'n0000259150', '00000', 'n0000259224', '00000', 'n0000259601', '00000', 'n0000259675', '00000', 'n0000260052', '00000', 'n0000260126', '00000', 'n0000260503', '00000', 'n0000260577', '00000', 'n0000260953', '00000', 'n0000261027', '00000', 'n0000261402', '00000', 'n0000261476', '00000', 'n0000261853', '00000', 'n0000261927', ...

# %%
import re
text = "dctv"
def has_cyrillic(text): # проверяем, слово на русском или нет 
    return bool(re.search('[а-яА-Я]', text))

# %%
import re
text = "路"
def has_english(text): # проверяем, слово на английском или нет 
    return bool(re.search('[a-zA-z]', text))

# %%
data_spbu.iloc[205, 0]
data_spbu = data_spbu[~data_spbu[0].str.endswith('.pdf/')] # удаляем строки из датафрейма, которые пдфки

# %%
morph = pymorphy2.MorphAnalyzer()


def lemmatization(data_spbu):
    df = data_spbu.copy()
    list_errors = list()
    for i in tn(data_spbu.index):
        if i < 30433:
            sub_string = data_spbu.iloc[i, 2]
        if type(sub_string) is str:
            word_list = nltk.word_tokenize(sub_string.lower()) # делаем маленькие буквы, разбиваем текст на токены (из 3-го столбика по каждой строке)
            word_list = [word for word in word_list if (word not in russian_stopwords and not word.isnumeric() and word not in english_stopwords and (has_cyrillic(word) or has_english(word)))] # удаляем слова, которые в англ и русс стоп-словах или если они числовые (строчки)
            try:
                word_list = [morph.parse(j)[0].normal_form for j in word_list] # нормальная форма токена
                df.iloc[i, 2] = ' '.join(word_list) # заменяем 3 столбик на лемматизированный текст
            except:
                list_errors.append(i) # в лист ошибок добавляем номер строки, в которой ошибка 
                df.iloc[i, 2] = '' # зануляем строку, в которой ошибка
    return df, list_errors 
df, list_errors = lemmatization(data_spbu) # переменные из ретерна, которые возвращает функция 
# df.to_csv('df.csv') # сохраняем обработанный датафрейм в новый csv для последующего использования (токенизированный и почищенный)

# %%
df.head(10)
# Out:
#                                                    0  \
# 0                                   https://spbu.ru/
# 1             https://cabinet.spbu.ru/Account/LogOn/
# 2                                 http://bb.spbu.ru/
# 3                            https://events.spbu.ru/
# 4          https://cabinet.spbu.ru/Account/Register/
# 5  https://dev.abiturient.spbu.ru/prezentatsii-ob...
# 6                             https://store.spbu.ru/
# 7                              http://forum.spbu.ru/
# 8                   https://online.spbu.ru/partners/
# 9                     https://store.spbu.ru/address/
#
#                               1  \
# 0  2023-04-14T00:56:50.6368499Z
# 1  2023-04-14T00:57:02.6226399Z
# 2  2023-04-14T00:57:02.6225294Z
# 3  2023-04-14T00:57:03.8827793Z
# 4  2023-04-14T00:57:06.6414451Z
# 5  2023-04-14T00:57:02.6224252Z
# 6  2023-04-14T00:57:03.8926359Z
# 7  2023-04-14T00:57:04.6276693Z
# 8  2023-04-14T00:57:04.6238848Z
# 9  2023-04-14T00:57:34.6261438Z
#
#                                                    2
# 0  главный санкт-петербургский государственный ун...
# 1  вход .mobile_header font-size 11pt important л...
# 2  blackboard learn html font 0.78em `` lucida gr...
# 3  управление организация публичный мероприятие с...
# 4  регистрация новый пользователь .mobile_header ...
# 5  презентация образовательный программа приёмный...
# 6  интернет-магазин спбгуинтернет‑магазинкаталог ...
# 7  общественный обсуждение общественный обсуждени...
# 8  центр развитие электронный образовательный рес...
# 9  купить интернет-магазин спбгуинтернет‑магазинк...

# %%
for i in nltk.word_tokenize(data_spbu.iloc[426,2]): #смотрим в чем ошибка в 426 строке 
     try:
          morph.parse(i)[0].normal_form
     except:
          print(i)
# Out:
# .����n��𗳧�t��n\�6K��9�ӿ�

# %%
data_spbu.iloc[3830, 2]
morph.parse("государственная")[0].normal_form
# Out:
# 'государственный'

# %%
data_spbu.iloc[426, 0]
word_list1 = nltk.word_tokenize(data_spbu.iloc[426, 0].lower()) # токенизированная строка
print(word_list1)
# Out:
# ['https', ':', '//spbu.ru/file/63504/download', '?', 'token=zfhkxefx/']

# %%
data_spbu.iloc[426, 0]
# Out:
# 'https://spbu.ru/file/63504/download?token=zfHKXEFx/'

# %%
list_errors = [426, # лист с ошибками
3306,
4132,
7316,
8177,
8209,
8277,
8354,
8500,
8525,
8851,
9725,
9726,
9784,
9829,
9857,
9957,
9994,
10082,
10430,
10431,
10432,
10966,
11017,
11025,
11045,
11215,
11306,
11533,
11691,
11784,
12063,
12214,
12273,
12526,
12528,
12760,
12769,
12884,
12927,
12974,
14278,
15082,
16247,
16267,
16316,
16360,
16600,
16803,
17497,
17772,
18650,
18690,
18817,
20048,
20664,
21126,
21710,
22305,
22794,
23144,
23278,
23613,
23720,
23766,
23838,
23911,
24235,
24485,
25062,
25117,
25512,
25775,
26357,
27083,
27179,
27583,
29401,
29573,
29743,
30433]

# %%
d = data_spbu.iloc[205, 2]
def has_cyrillic(d): # проверяем че происходит в строке 205 
    return bool(re.search('[а-яА-Я]', d))
print(has_cyrillic(d))
# Out:
# True

# %%
d = data_spbu.iloc[205, 2]
def has_english(d): # проверяем че происзодит в строке 205 
    return bool(re.search('[a-zA-z]', d))
print(has_english(d))
# Out:
# True

# %%
morph = pymorphy2.MorphAnalyzer()
df = data_spbu.copy()

# %%
# мне нужен словарь, в котором слова - ключи, а значения(которые соответствуют этим ключам - списки)
# то есть каждому слову соответствует список ссылок из df.csv, в которых содержится это слово
#

# %%
df = pd.read_csv('df.csv', index_col=0)
list_errors = [426, 3306, 4132,7316, 8177, 8209, 8277, 8354, 8500, 8525, 8851, 9725, 9726, 9784, 9829, 9857, 9957, 9994, 10082, 10430, 10431, 
               10432, 10966, 11017, 11025, 11045, 11215, 11306, 11533, 11691, 11784, 12063, 12214, 12273, 12526, 12528, 12760, 12769, 12884,
               12927, 12974, 14278, 15082, 16247, 16267, 16316, 16360, 16600, 16803, 17497, 17772, 18650, 18690, 18817, 20048, 20664, 21126,
               21710, 22305, 22794, 23144, 23278, 23613, 23720, 23766, 23838, 23911, 24235, 24485, 25062, 25117, 25512, 25775, 26357, 27083, 
               27179, 27583, 29401, 29573, 29743, 30433] 
# list_errors = lemmatization(data_spbu)
def create_dict(df, list_errors):
    my_dict = {}
    df_size = df.shape[0]   
    for i in tn(df.index):  # цикл, который обрабатывает строки
        if i not in list_errors and isinstance(df.iloc[i][2], str) and i < df_size:
            tokens_list = list()
            tokens_list = df.iloc[i][2].split() # если строка не встречается в листе ошибок (то что не получилось обработать на лемматизации)
            for j in tokens_list: # тут цикл, который обрабатывает токены (он смотрит, есть ли какая-то запись в словаре, соответствующая конкретному слову)
                if j in my_dict: # если ключ уже есть, то добавляем в список ссылку
                    my_dict[j].append(df.iloc[i][0]) 
                else:  
                    my_dict[j] = [df.iloc[i][0]] # пыталась тут добавить ключ и значение (то есть ссылку), если их нет в словаре 

    return my_dict

my_dict = create_dict(df, list_errors)           
            # если запись в словаре есть - идем дальше, если записи в словаре нет - добавляем эту строку в лист для конкретного ключа
            # ну либо (если первый раз встречается) создаем лист, в который записывается значение строки для ключа
# Out:
#   0%|          | 0/30433 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 23
#      19                     my_dict[j] = [df.iloc[i][0]] # пыталась тут добавить ключ и значение (то есть ссылку), если их нет в словаре
#      21     return my_dict
# ---> 23 my_dict = create_dict(df, list_errors)
#
# Cell In[8], line 12, in create_dict(df, list_errors)
#      10 df_size = df.shape[0]
#      11 for i in tn(df.index):  # цикл, который обрабатывает строки
# ---> 12     if i not in list_errors and isinstance(df.iloc[i][2], str) and i < df_size:
#      13         tokens_list = list()
#      14         tokens_list = df.iloc[i][2].split() # если строка не встречается в листе ошибок (то что не получилось обработать на лемматизации)
#
# File c:\Users\User\anaconda3\envs\Work\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\User\anaconda3\envs\Work\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\User\anaconda3\envs\Work\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
print(my_dict)

# %%
import json # сохраняем словарь в файл 
with open('result.json', 'w') as fp:
    json.dump(my_dict, fp)
